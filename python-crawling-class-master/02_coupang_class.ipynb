# %% [markdown]
# # 웹 크롤링(2)
# 크롤링 사이트: https://www.coupang.com
#
# ## 크롤링 절차
# 1. 사이트의 html을 읽어들이기: requests.get(url) 사용
#     * http://www.useragentstring.com/
#
#
#
# 2. 텍스트 형태의 데이터를 html 태그별로 구분하여 파싱하기 : BeutifulSoup
#
# 3. 특정 태그값만 찾기 : findAll, find
#
# 4. 필요한 데이터값 정제하기
#
# 5. 데이터 저장하기

# %%
from bs4 import BeautifulSoup
import csv
import requests
import pandas as pd

# %%
# 헤더 설정 (유저의 클라이언트 정보)
headers = {'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/83.0.4103.106 Safari/537.36'}

# %%
# url 설정
product_name = '김치'
# https://www.coupang.com/np/search?component=&q=김치&channel=user
url = f"https://www.coupang.com/np/search?component=&q={product_name}&channel=user"

# %%
# get html
response = requests.get(url, headers = headers)

# %%
# BeautifulSoup을 활용하여 데이터 파싱
soup = BeautifulSoup(response.text, "html.parser")
# print(soup)

# %%
#상품명
# <div class="name">비비고 썰은배추김치, 1.8kg, 1개</div>
names = soup.findAll('div', {'class':'name'})

for item in names :
    print(item.text)
# Out:
# [입점특가]100%국산 30년 전통 전라도 파김치, 1kg, 1개
# 한경 전라도 배추김치3 5 10kg, 생포기김치10kg
# 종가집 포기김치, 4kg, 1개
# 종가집 썰어담은 맛김치, 1.7kg, 1봉
# 비비고 썰은배추김치, 1.8kg, 1개
# 100% 국내산 늘솜이랑 해풍 생 포기김치 3kg 5kg 10kg
# 늘해랑 전라도 배추김치, 10kg, 1박스
# 늘해랑 전라도 배추김치, 10kg, 1박스
# 종가집 맛김치, 1kg, 1개
# [청원오가닉] 청원 포기김치 국산 HACCP 인증 시원하고 깊은맛, 10kg, 1개
# 곰곰 배추 김치, 10kg, 1개
# 곰곰 국내산 썰은 배추 김치, 1kg, 1개
# 이혜정의 맛있는 포기김치 11kg, 없음, 상세설명 참조
# 곰곰 국내산 포기 김치 (냉장), 4kg, 1개
# [입점특가] 100% 국산 전라도 포기김치, 3kg, 1팩
# 곰곰 썰은 배추김치, 10kg, 1개
# 곰곰 국내산 썰은 배추 김치, 1.8kg, 1개
# 비비고 썰은 배추김치, 500g, 1통
# 곰곰 국내산 포기 김치 (냉장), 4.9kg, 1개
# 비비고 썰은 배추김치, 3kg, 1개
# 종가집 현명한 주부의 포기김치, 10kg, 1개
# CJ제일제당 비비고 더풍부한 맛 썰은배추김치, 900g, 1개
# 올바른빛깔 프리미엄 김치, 1박스, 10kg
# 천년한옥 포기김치, 5kg, 1박스
# 비비고 총각김치, 1.5kg, 1개
# 늘해랑 전라도 배추김치, 5kg, 1박스
# 이보은의 잘차린 포기김치 5kg + 5kg 총10kg
# 참들 생포기김치, 10kg, 1개
# [종가집] 포기김치1kg+총각김치1kg+열무김치1kg+깍두기1kg(무료증정), 포기1kg+총각1kg+열무1kg+깍두기1kg(증정)
# 곰곰 국내산 포기 김치 (냉장), 2kg, 1개
# 비비고 석박지를 넣은 포기김치, 3kg, 1개
# [청원오가닉] 청원 포기김치 국산 HACCP 인증 시원하고 깊은맛, 10kg, 1개
# 종가집 총각김치, 2.5kg, 1개
# [올바른 배추김치] 전라도 김치, 일반10kg
# 해드림 생포기김치 10kg, 1개
# 친정김치 배추김치 3kg 5kg 10kg, 1개
# 봉화 청량산 김치 배추 포기김치 (프리미엄 올바른빛깔 김치), 10kg

# %%
# <div class="price">  <span class="price-info">  <span class="instant-discount-rate">6%</span>   <del class="base-price">14,900</del>  </span> <em class="sale "> <strong class="price-value">13,890</strong>원   <span class="badge rocket"> <img src="//image6.coupangcdn.com/image/badges/falcon/v1/web/rocket-fresh@2x.png" height="16" alt="로켓배송">  </span>  </em>   <span class="unit-price">(<em>100</em>g당 <em>772</em>원) </span>  </div>
# <strong class="price-value">13,890</strong>원 
prices = soup.findAll('strong', {'class':'price-value'})

# for item in prices :
#     print(item.text)

# %%
name_list = []
price_list = []

# %%
# 광고 데이터(i=0일때)는 가격이 나오지 않으므로 리스트 생성 시, 제외
i = 0
for item in names :
    if(i > 0) : 
        name_list.append(item.text)        
    i = i + 1
    
for item in prices :
    price_list.append(item.text)

# %%
result_file_name = "coupang_kimch.csv"
for k in range(len(price_list)) :
#     print("*상품명 : ", name_list[k+1], ",    *가격 : ",price_list[k])
    result = pd.DataFrame(data={'상품명' : name_list, '가격' : price_list})
    result.to_csv(result_file_name, header = False, index = False, encoding='utf-8-sig')

result
# Out:
#                                                   상품명      가격
# 0                      한경 전라도 배추김치3 5 10kg, 생포기김치10kg  29,800
# 1                                   종가집 포기김치, 4kg, 1개  27,190
# 2                             종가집 썰어담은 맛김치, 1.7kg, 1봉  16,900
# 3                               비비고 썰은배추김치, 1.8kg, 1개  16,750
# 4                100% 국내산 늘솜이랑 해풍 생 포기김치 3kg 5kg 10kg  15,900
# 5                             늘해랑 전라도 배추김치, 10kg, 1박스  29,900
# 6                             늘해랑 전라도 배추김치, 10kg, 1박스  29,900
# 7                                    종가집 맛김치, 1kg, 1개   9,950
# 8      [청원오가닉] 청원 포기김치 국산 HACCP 인증 시원하고 깊은맛, 10kg, 1개  45,000
# 9                                  곰곰 배추 김치, 10kg, 1개  15,900
# 10                           곰곰 국내산 썰은 배추 김치, 1kg, 1개   8,600
# 11                    이혜정의 맛있는 포기김치 11kg, 없음, 상세설명 참조  43,870
# 12                         곰곰 국내산 포기 김치 (냉장), 4kg, 1개  23,150
# 13                   [입점특가] 100% 국산 전라도 포기김치, 3kg, 1팩  14,900
# 14                               곰곰 썰은 배추김치, 10kg, 1개  14,190
# 15                         곰곰 국내산 썰은 배추 김치, 1.8kg, 1개  14,220
# 16                              비비고 썰은 배추김치, 500g, 1통   7,200
# 17                       곰곰 국내산 포기 김치 (냉장), 4.9kg, 1개  26,100
# 18                               비비고 썰은 배추김치, 3kg, 1개  27,600
# 19                         종가집 현명한 주부의 포기김치, 10kg, 1개  45,500
# 20                 CJ제일제당 비비고 더풍부한 맛 썰은배추김치, 900g, 1개   9,880
# 21                           올바른빛깔 프리미엄 김치, 1박스, 10kg  14,500
# 22                                천년한옥 포기김치, 5kg, 1박스  27,500
# 23                                비비고 총각김치, 1.5kg, 1개  15,800
# 24                             늘해랑 전라도 배추김치, 5kg, 1박스  19,900
# 25                      이보은의 잘차린 포기김치 5kg + 5kg 총10kg  41,310
# 26                                 참들 생포기김치, 10kg, 1개  27,900
# 27  [종가집] 포기김치1kg+총각김치1kg+열무김치1kg+깍두기1kg(무료증정), 포기...  28,300
# 28                         곰곰 국내산 포기 김치 (냉장), 2kg, 1개  13,580
# 29                          비비고 석박지를 넣은 포기김치, 3kg, 1개  21,900
# 30     [청원오가닉] 청원 포기김치 국산 HACCP 인증 시원하고 깊은맛, 10kg, 1개  45,000
# 31                                종가집 총각김치, 2.5kg, 1개  20,070
# 32                          [올바른 배추김치] 전라도 김치, 일반10kg  37,900
# 33                                 해드림 생포기김치 10kg, 1개  14,900
# 34                         친정김치 배추김치 3kg 5kg 10kg, 1개  33,900
# 35            봉화 청량산 김치 배추 포기김치 (프리미엄 올바른빛깔 김치), 10kg  29,900

# %%
## (실습1) 쿠팡 케이스별로 크롤링 하는 경우
product_name = '종가집 김치'
page_no=1
min_price=20000
max_price=40000

result_file_name ='쿠팡_result_2'

url = f"https://www.coupang.com/np/search?component=&q={product_name}&channel=user&page={page_no}&minPrice={min_price}&maxPrice={max_price}"

# %%
# get html
response = requests.get(url, headers = headers)

# %%
soup = BeautifulSoup(response.text, "html.parser")
names = soup.findAll('div', {'class':'name'})
prices = soup.findAll('strong', {'class':'price-value'})

name_list = []
price_list = []

i = 0
for item in names :
    if(i > 0) : 
        name_list.append(item.text)        
    i = i + 1
    
for item in prices :
    price_list.append(item.text)

for k in range(len(price_list)) :
    result = pd.DataFrame(data={'상품명' : name_list, '가격' : price_list})
    result.to_csv(result_file_name, header = False, index = False, encoding='utf-8-sig')

result
